# %% [markdown]
# # Домашнее задание "Продвинутая линейная алгебра".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Дан объект в $2D$ пространстве

# %%
import numpy as np
import matplotlib.pyplot as plt

A = [
[-100, -100, 1],
[-100, 100, 1],
[100, 100, 1],
[0, 0, 1],
[100, -100, 1],
[-100, -100, 1]
]

A = np.array(A)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# При помощи линейных отображений:
# - Уменьшить объект в два раза
# - Повернуть на 130 градусов
# - Отразить объект относительно прямой y=x (поможет матрица `[[0, 1, 0], [1, 0, 0], [0, 0, 1]]`)

# %%
B = np.array([[0.5,0, 0],[0, 0.5, 0], [0, 0, 1]])
res = B @ A.T
tt = res.T
A = np.array(tt)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
rotate = np.radians(130)
rotation_matrix = np.array([
    [np.cos(rotate), -np.sin(rotate), 0],
    [np.sin(rotate),  np.cos(rotate), 0],
    [0, 0, 1]
])
A = rotation_matrix @ A.T
A = A.T

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
another_matrix = np.array([[0, 1, 0], [1, 0, 0], [0, 0, 1]])
A = another_matrix @ A.T
A = A.T

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Найдите спектральное разложение матрицы:
# ```
# m = np.array([[1, 2],
#               [2, 3]])
# print(m)
# ```

# %%
m = np.array([[1, 2],
              [2, 3]])
values, vectors = np.linalg.eig(m)
print(values)
print(vectors)
# Out:
# [-0.23606798  4.23606798]
# [[-0.85065081 -0.52573111]
#  [ 0.52573111 -0.85065081]]

# %%
D = np.diag(values)
S = vectors
res = S @ D @ S.T
print(res)
# Out:
# [[1. 2.]
#  [2. 3.]]
