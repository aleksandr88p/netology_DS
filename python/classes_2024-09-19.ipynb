# %% [markdown]
# # Практика

# %%
from analytics_lib import AnyName

# %%
from analytics_lib import *  # очень нехорошо так делать

# %%
def calculation_2(x, y, z):
    """Просто функция"""
    return x**2 + y**2 + z**2

# %%
class AnyName:  # CamelCase snake_case
    BANK = 'Сбер'
    
    def __init__(self, currency='EUR', *args, **kwargs):
        # выполняется при обращении к классу
        print('Создаем все атрибуты, необходимые для работы класса')
        self.x = 0
        self.currency = currency
        self.price = 100
        self.vat = 0.2
        
        # приватные атрибуты
        self._api_version = '5.151'  # намек на то, что менять атрибут вне кода класса опасно
        self.__secr_attr = 123  # запрет на изменение атрибута вне кода класса
    
    # функции в классах называются методы
    def method_1(self):
        # x = 1  # просто переменная
        self.x = 1  # это атрибут
        
    def method_2(self):
        self.x += 1
        print(self.x, self.currency, self.__secr_attr)
        
    @staticmethod  # декоратор
    def calculation(x, y, z):
        """Просто функции внутри классов"""
        return x**2 + y**2 + z**2
    
    @property
    def calculated_attr(self, discount=0.1):
        """Вычислимый атрибут - посчитать цену без НДС с учетом скидки discount"""
        price_w_vat = self.price / (1+self.vat)
        return price_w_vat * (1 - discount)

# %%
a = AnyName()
# Out:
# Создаем все атрибуты, необходимые для работы класса

# %%
a.calculated_attr
# Out:
# 75.00000000000001

# %%
a.calculation(1, 2, 3)
# Out:
# 14

# %%
a.method_2()
# Out:
# 1 EUR 123

# %%
a.__secr_attr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 a.__secr_attr
#
# AttributeError: 'AnyName' object has no attribute '__secr_attr'

# %%
a._api_version
# Out:
# '5.151'

# %%
a._api_version = '6.0'

# %%
a.BANK
# Out:
# 'Сбер'

# %%
a.method_2()
# Out:
# 1 EUR

# %%
a.method_1()

# %%
a.x = 2
a.x
# Out:
# 2

# %%
a.method_2()
# Out:
# 3

# %%
datetime.strptime('2024-09-19', '%d.%m.%Y')

# %%
ValueError

# %%
class GAParamsDateError(Exception):
    pass

# %%
response = {'response': 'Error: wrong date', 'status_code': 400}

# %%
if response['status_code'] == 400:
    raise GAParamsDateError
# Out:
# ---------------------------------------------------------------------------
# GAParamsDateError                         Traceback (most recent call last)
# Cell In[48], line 2
#       1 if response['status_code'] == 400:
# ----> 2     raise GAParamsDateError
#
# GAParamsDateError:

# %%
def func_1(x, z):
    x += 1
    z = z * 2
    
    return x, z


def func_2(y, z):
    print(y, z)

# %%
res = func_1(1, 2)

# %%
res
# Out:
# (2, 4)

# %%
func_2(123, res[1])
# Out:
# 123 4

# %% [markdown]
# ### Абстрактный класс
# Нужны, чтобы при наследовании родительского класса вы ОБЯЗАТЕЛЬНО переопределяли некоторые методы.

# %%
from abc import ABC, abstractmethod

# %%
class Report(ABC):
    @abstractmethod
    def sources(self):
        pass

    @abstractmethod
    def calculation(self):
        pass

    def write_to_db(self):
        # в методе запускается процесс вычислений и записи результатов
        pass

# %%
class SalesReport(Report):
    def sources(self):
        print('Определяем источники данных')

    def calculation(self):
        print('Пишем код вычислений')

# %%
class MarketingReport(Report):
    def sources(self):
        print('Определяем источники данных')

    def calculation(self):
        print('Пишем код вычислений')

# %%
class MarketingEfficiencyReport(SalesReport, MarketingReport)

# %%
s = SalesReport()

# %%
s.sources()
# Out:
# Определяем источники данных

# %%
s.calculation()
# Out:
# Пишем код вычислений

# %%
s.write_to_db()

# %% [markdown]
# # Требования к отчету
# (в хронологическом порядке)
#
# 1. Нужен отчет по трафику (визиты по дням)
# 2. Сделайте таблицу попроще
# 3. А можно сразу очень много строк получить?
#
# [Демо-счетчик](https://metrika.yandex.ru/stat/traffic?sort=-ym%3As%3Avisits&period=2020-08-01%3A2020-09-06&accuracy=1&id=44147844&stateHash=5d3ee51607d6bde783131e11) Яндекс.Метрики

# %%
import requests
import json

# %%
API_URL = 'https://api-metrika.yandex.ru/stat/v1/data'
METRIKA_ROWS_LIMIT = 5  # max 100000

DEMO_COUNTER = 44147844

# %%
class Metrika:
    def __init__(self, token='', counter=DEMO_COUNTER, start_date='2020-09-01', end_date='2020-09-10'):
        self.counter = counter
        self.limit = METRIKA_ROWS_LIMIT
        self.start_date = start_date
        self.end_date = end_date
        
        if token:
            self.headers = {'Authorization': 'OAuth ' + token}
        else:
            self.headers = ''  # для демо-счетчика заголовок запроса должен быть пустым
        
        self.dimensions = ''  # что мы хотим увидеть в строках отчета
        self.metrics = ''  # в столбцах
        self.report = []  # сам отчет
        
    def api_request(self, offset=1):
        """Запрос к API Метрики, возвращает словарь с отчетом"""
        params = {
            'id': self.counter,
            'date1': self.start_date,
            'date2': self.end_date,
            'metrics': self.metrics,
            'dimensions': self.dimensions,
            'limit': self.limit,
            'offset': offset,
            'accuracy': 1,
        }
        
        response = requests.get(API_URL, params=params, headers=self.headers)
        return response.json()['data']
    
    def traffic(self):
        """Отчет по посещаемости"""
        self.metrics = 'ym:s:visits'
        self.dimensions = 'ym:s:date'
        
        report = self.full_report()
        self.report = report
        
    def browsers(self):
        """Отчет по браузерам"""
        self.metrics = 'ym:s:visits'
        self.dimensions = 'ym:s:date,ym:s:browser'
        
        report = self.full_report()
        self.report = report
    
    def reformat_api_report(self):
        """Упрощение отчета до списка списков"""
        reformatted_report = []

        for line in self.report:
            dimensions = [x['name'] for x in line['dimensions']]
            reformatted_report.append(dimensions + line['metrics'])

        self.report_formatted = reformatted_report
    
    def full_report(self):
        """Постраничная выгрузка из Метрики"""
        full_data = []
        offset = 1
        
        while True:
            print('Starting offset {}'.format(offset))
            data = self.api_request(offset=offset)
            full_data += data
            
            offset += self.limit
            if not data or len(data) < self.limit:
                break
        
        return full_data

    def to_csv(self, filename):
        with open(filename, 'w') as f:
            f.write(json.dumps(self.report_formatted))

# %%
m = Metrika(start_date='2024-08-01', end_date='2024-09-18')

# %%
m.traffic()
# Out:
# Starting offset 1
# Starting offset 6
# Starting offset 11
# Starting offset 16
# Starting offset 21
# Starting offset 26
# Starting offset 31
# Starting offset 36
# Starting offset 41
# Starting offset 46

# %%
m.report
# Out:
# [{'dimensions': [{'name': '2024-08-05'}], 'metrics': [417.0]},
#  {'dimensions': [{'name': '2024-09-13'}], 'metrics': [415.0]},
#  {'dimensions': [{'name': '2024-08-12'}], 'metrics': [413.0]},
#  {'dimensions': [{'name': '2024-09-03'}], 'metrics': [413.0]},
#  {'dimensions': [{'name': '2024-09-11'}], 'metrics': [408.0]},
#  {'dimensions': [{'name': '2024-08-07'}], 'metrics': [403.0]},
#  {'dimensions': [{'name': '2024-08-08'}], 'metrics': [400.0]},
#  {'dimensions': [{'name': '2024-09-17'}], 'metrics': [397.0]},
#  {'dimensions': [{'name': '2024-08-21'}], 'metrics': [396.0]},
#  {'dimensions': [{'name': '2024-09-16'}], 'metrics': [393.0]},
#  {'dimensions': [{'name': '2024-08-06'}], 'metrics': [389.0]},
#  {'dimensions': [{'name': '2024-09-06'}], 'metrics': [388.0]},
#  {'dimensions': [{'name': '2024-08-20'}], 'metrics': [386.0]},
#  {'dimensions': [{'name': '2024-09-04'}], 'metrics': [385.0]},
#  {'dimensions': [{'name': '2024-09-09'}], 'metrics': [381.0]},
#  {'dimensions': [{'name': '2024-09-10'}], 'metrics': [381.0]},
#  {'dimensions': [{'name': '2024-09-05'}], 'metrics': [380.0]},
#  {'dimensions': [{'name': '2024-08-13'}], 'metrics': [379.0]},
#  {'dimensions': [{'name': '2024-08-26'}], 'metrics': [368.0]},
#  {'dimensions': [{'name': '2024-08-14'}], 'metrics': [365.0]},
#  {'dimensions': [{'name': '2024-08-22'}], 'metrics': [362.0]},
#  {'dimensions': [{'name': '2024-08-30'}], 'metrics': [360.0]},
#  {'dimensions': [{'name': '2024-08-29'}], 'metrics': [356.0]},
#  {'dimensions': [{'name': '2024-09-12'}], 'metrics': [356.0]},
#  {'dimensions': [{'name': '2024-08-15'}], 'metrics': [345.0]},
#  {'dimensions': [{'name': '2024-08-19'}], 'metrics': [342.0]},
#  {'dimensions': [{'name': '2024-08-09'}], 'metrics': [341.0]},
#  {'dimensions': [{'name': '2024-08-28'}], 'metrics': [339.0]},
#  {'dimensions': [{'name': '2024-08-27'}], 'metrics': [337.0]},
#  {'dimensions': [{'name': '2024-08-16'}], 'metrics': [332.0]},
#  {'dimensions': [{'name': '2024-09-02'}], 'metrics': [332.0]},
#  {'dimensions': [{'name': '2024-09-18'}], 'metrics': [329.0]},
#  {'dimensions': [{'name': '2024-08-23'}], 'metrics': [316.0]},
#  {'dimensions': [{'name': '2024-08-02'}], 'metrics': [305.0]},
#  {'dimensions': [{'name': '2024-08-11'}], 'metrics': [288.0]},
#  {'dimensions': [{'name': '2024-08-01'}], 'metrics': [287.0]},
#  {'dimensions': [{'name': '2024-08-03'}], 'metrics': [260.0]},
#  {'dimensions': [{'name': '2024-08-10'}], 'metrics': [259.0]},
#  {'dimensions': [{'name': '2024-09-07'}], 'metrics': [247.0]},
#  {'dimensions': [{'name': '2024-09-15'}], 'metrics': [239.0]},
#  {'dimensions': [{'name': '2024-09-14'}], 'metrics': [237.0]},
#  {'dimensions': [{'name': '2024-08-24'}], 'metrics': [229.0]},
#  {'dimensions': [{'name': '2024-09-01'}], 'metrics': [229.0]},
#  {'dimensions': [{'name': '2024-08-04'}], 'metrics': [228.0]},
#  {'dimensions': [{'name': '2024-08-18'}], 'metrics': [223.0]},
#  {'dimensions': [{'name': '2024-08-31'}], 'metrics': [222.0]},
#  {'dimensions': [{'name': '2024-08-25'}], 'metrics': [212.0]},
#  {'dimensions': [{'name': '2024-09-08'}], 'metrics': [208.0]},
#  {'dimensions': [{'name': '2024-08-17'}], 'metrics': [192.0]}]

# %%
m.reformat_api_report()
m.report_formatted
# Out:
# [['2024-08-05', 417.0],
#  ['2024-09-13', 415.0],
#  ['2024-08-12', 413.0],
#  ['2024-09-03', 413.0],
#  ['2024-09-11', 408.0],
#  ['2024-08-07', 403.0],
#  ['2024-08-08', 400.0],
#  ['2024-09-17', 397.0],
#  ['2024-08-21', 396.0],
#  ['2024-09-16', 393.0],
#  ['2024-08-06', 389.0],
#  ['2024-09-06', 388.0],
#  ['2024-08-20', 386.0],
#  ['2024-09-04', 385.0],
#  ['2024-09-09', 381.0],
#  ['2024-09-10', 381.0],
#  ['2024-09-05', 380.0],
#  ['2024-08-13', 379.0],
#  ['2024-08-26', 368.0],
#  ['2024-08-14', 365.0],
#  ['2024-08-22', 362.0],
#  ['2024-08-30', 360.0],
#  ['2024-08-29', 356.0],
#  ['2024-09-12', 356.0],
#  ['2024-08-15', 345.0],
#  ['2024-08-19', 342.0],
#  ['2024-08-09', 341.0],
#  ['2024-08-28', 339.0],
#  ['2024-08-27', 337.0],
#  ['2024-08-16', 332.0],
#  ['2024-09-02', 332.0],
#  ['2024-09-18', 329.0],
#  ['2024-08-23', 316.0],
#  ['2024-08-02', 305.0],
#  ['2024-08-11', 288.0],
#  ['2024-08-01', 287.0],
#  ['2024-08-03', 260.0],
#  ['2024-08-10', 259.0],
#  ['2024-09-07', 247.0],
#  ['2024-09-15', 239.0],
#  ['2024-09-14', 237.0],
#  ['2024-08-24', 229.0],
#  ['2024-09-01', 229.0],
#  ['2024-08-04', 228.0],
#  ['2024-08-18', 223.0],
#  ['2024-08-31', 222.0],
#  ['2024-08-25', 212.0],
#  ['2024-09-08', 208.0],
#  ['2024-08-17', 192.0]]

# %%
m.browsers()
m.report
# Out:
# Starting offset 1
# Starting offset 6
# Starting offset 11
# Starting offset 16
# Starting offset 21
# Starting offset 26
# Starting offset 31
# Starting offset 36
# Starting offset 41
# Starting offset 46
# Starting offset 51
# Starting offset 56
# Starting offset 61
# Starting offset 66
# Starting offset 71
# Starting offset 76
# Starting offset 81
# Starting offset 86
# Starting offset 91
# Starting offset 96
# Starting offset 101
# Starting offset 106
# Starting offset 111
# Starting offset 116
# Starting offset 121
# Starting offset 126
# Starting offset 131
# Starting offset 136
# Starting offset 141
# Starting offset 146
# Starting offset 151
# Starting offset 156
# Starting offset 161
# Starting offset 166
# Starting offset 171
# Starting offset 176
# Starting offset 181
# Starting offset 186
# Starting offset 191
# Starting offset 196
# Starting offset 201
# Starting offset 206
# Starting offset 211
# Starting offset 216
# Starting offset 221
# Starting offset 226
# Starting offset 231
# Starting offset 236
# Starting offset 241
# Starting offset 246
# Starting offset 251
# Starting offset 256
# Starting offset 261
# Starting offset 266
# Starting offset 271
# Starting offset 276
# Starting offset 281
# Starting offset 286
# Starting offset 291
# Starting offset 296
# Starting offset 301
# Starting offset 306
# Starting offset 311
# Starting offset 316
# Starting offset 321
# Starting offset 326
# Starting offset 331
# Starting offset 336
# Starting offset 341
# Starting offset 346
# Starting offset 351
# Starting offset 356
# Starting offset 361
# Starting offset 366
# Starting offset 371
# Starting offset 376
# Starting offset 381
# Starting offset 386
# Starting offset 391
# Starting offset 396
# Starting offset 401
# Starting offset 406
# Starting offset 411
# Starting offset 416
# Starting offset 421
# Starting offset 426
# Starting offset 431
# Starting offset 436
# Starting offset 441
# Starting offset 446
# Starting offset 451
# Starting offset 456
# Starting offset 461
# Starting offset 466
# Starting offset 471
# Starting offset 476
# Starting offset 481
# Starting offset 486
# Starting offset 491
# Starting offset 496
# Starting offset 501
# Starting offset 506
# Starting offset 511
# Starting offset 516
# Starting offset 521
# Starting offset 526
# Starting offset 531
# Starting offset 536
# Starting offset 541
# Starting offset 546
# Starting offset 551
# Starting offset 556
# Starting offset 561
# Starting offset 566
# Starting offset 571
# Starting offset 576
# Starting offset 581
# Starting offset 586
# Starting offset 591
# Starting offset 596
# Starting offset 601
# Starting offset 606
# Starting offset 611
# Starting offset 616
# Starting offset 621
# Starting offset 626
# Starting offset 631
# Starting offset 636
# Starting offset 641
# Starting offset 646
# Starting offset 651
# Starting offset 656
# Starting offset 661
# Starting offset 666
# Starting offset 671
# Starting offset 676
# Starting offset 681
# Starting offset 686
# Starting offset 691
# Starting offset 696
# Starting offset 701
# Starting offset 706
# Starting offset 711
# Starting offset 716
# Starting offset 721
# Starting offset 726
# Starting offset 731
# Starting offset 736
# [{'dimensions': [{'name': '2024-08-07'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [225.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [225.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [221.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [217.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [216.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [213.0]},
#  {'dimensions': [{'name': '2024-08-20'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [209.0]},
#  {'dimensions': [{'name': '2024-08-05'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [208.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [206.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [201.0]},
#  {'dimensions': [{'name': '2024-08-12'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [200.0]},
#  {'dimensions': [{'name': '2024-08-26'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [200.0]},
#  {'dimensions': [{'name': '2024-08-06'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [199.0]},
#  {'dimensions': [{'name': '2024-08-21'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [199.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [199.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [196.0]},
#  {'dimensions': [{'name': '2024-08-13'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [194.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [191.0]},
#  {'dimensions': [{'name': '2024-08-08'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [187.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [187.0]},
#  {'dimensions': [{'name': '2024-08-27'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [185.0]},
#  {'dimensions': [{'name': '2024-08-14'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [183.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [179.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [179.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [178.0]},
#  {'dimensions': [{'name': '2024-08-19'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [170.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [167.0]},
#  {'dimensions': [{'name': '2024-08-15'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [163.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [163.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [163.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [163.0]},
#  {'dimensions': [{'name': '2024-08-16'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [147.0]},
#  {'dimensions': [{'name': '2024-08-09'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [136.0]},
#  {'dimensions': [{'name': '2024-08-11'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [124.0]},
#  {'dimensions': [{'name': '2024-08-10'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [120.0]},
#  {'dimensions': [{'name': '2024-08-03'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [116.0]},
#  {'dimensions': [{'name': '2024-08-02'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [111.0]},
#  {'dimensions': [{'name': '2024-08-01'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [108.0]},
#  {'dimensions': [{'name': '2024-08-05'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [104.0]},
#  {'dimensions': [{'name': '2024-08-08'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [104.0]},
#  {'dimensions': [{'name': '2024-08-01'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [102.0]},
#  {'dimensions': [{'name': '2024-08-18'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [100.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [100.0]},
#  {'dimensions': [{'name': '2024-08-02'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [99.0]},
#  {'dimensions': [{'name': '2024-08-06'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [98.0]},
#  {'dimensions': [{'name': '2024-08-09'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [98.0]},
#  {'dimensions': [{'name': '2024-08-03'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [95.0]},
#  {'dimensions': [{'name': '2024-08-12'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [95.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [95.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [93.0]},
#  {'dimensions': [{'name': '2024-08-25'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [93.0]},
#  {'dimensions': [{'name': '2024-08-04'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [92.0]},
#  {'dimensions': [{'name': '2024-08-11'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [92.0]},
#  {'dimensions': [{'name': '2024-08-04'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [91.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [91.0]},
#  {'dimensions': [{'name': '2024-08-14'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [90.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [88.0]},
#  {'dimensions': [{'name': '2024-08-15'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [87.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [86.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [85.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [85.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [84.0]},
#  {'dimensions': [{'name': '2024-08-13'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [83.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [83.0]},
#  {'dimensions': [{'name': '2024-08-16'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [82.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [82.0]},
#  {'dimensions': [{'name': '2024-09-08'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [82.0]},
#  {'dimensions': [{'name': '2024-08-17'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [81.0]},
#  {'dimensions': [{'name': '2024-08-21'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [81.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [81.0]},
#  {'dimensions': [{'name': '2024-08-31'},
#    {'icon_id': '6',
#     'icon_type': 'browser',
#     'name': 'Google Chrome',
#     'id': '6'}],
#   'metrics': [80.0]},
#  {'dimensions': [{'name': '2024-08-07'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [79.0]},
#  {'dimensions': [{'name': '2024-08-20'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [78.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [78.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [77.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [77.0]},
#  {'dimensions': [{'name': '2024-08-10'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [75.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [74.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [73.0]},
#  {'dimensions': [{'name': '2024-08-26'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [72.0]},
#  {'dimensions': [{'name': '2024-08-19'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [71.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [71.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [71.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [69.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [68.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [68.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [66.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [66.0]},
#  {'dimensions': [{'name': '2024-08-18'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [65.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [65.0]},
#  {'dimensions': [{'name': '2024-09-08'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [65.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [63.0]},
#  {'dimensions': [{'name': '2024-08-31'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [63.0]},
#  {'dimensions': [{'name': '2024-08-17'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [61.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [61.0]},
#  {'dimensions': [{'name': '2024-08-27'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [58.0]},
#  {'dimensions': [{'name': '2024-08-25'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [56.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '83',
#     'icon_type': 'browser',
#     'name': 'Chrome Mobile',
#     'id': '83'}],
#   'metrics': [51.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [44.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [40.0]},
#  {'dimensions': [{'name': '2024-08-02'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [37.0]},
#  {'dimensions': [{'name': '2024-08-20'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [37.0]},
#  {'dimensions': [{'name': '2024-08-12'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [34.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [33.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [32.0]},
#  {'dimensions': [{'name': '2024-08-09'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [31.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [31.0]},
#  {'dimensions': [{'name': '2024-08-26'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [31.0]},
#  {'dimensions': [{'name': '2024-08-05'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [30.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [30.0]},
#  {'dimensions': [{'name': '2024-08-21'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [29.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [29.0]},
#  {'dimensions': [{'name': '2024-08-14'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [28.0]},
#  {'dimensions': [{'name': '2024-08-27'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [28.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [28.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [28.0]},
#  {'dimensions': [{'name': '2024-08-07'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [27.0]},
#  {'dimensions': [{'name': '2024-08-21'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [27.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [27.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [27.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [27.0]},
#  {'dimensions': [{'name': '2024-08-13'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [26.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [26.0]},
#  {'dimensions': [{'name': '2024-08-15'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [25.0]},
#  {'dimensions': [{'name': '2024-08-27'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [25.0]},
#  {'dimensions': [{'name': '2024-08-31'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [25.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [25.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [25.0]},
#  {'dimensions': [{'name': '2024-08-05'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [24.0]},
#  {'dimensions': [{'name': '2024-08-09'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [24.0]},
#  {'dimensions': [{'name': '2024-08-16'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [24.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [24.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [24.0]},
#  {'dimensions': [{'name': '2024-08-08'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [23.0]},
#  {'dimensions': [{'name': '2024-08-26'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [23.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [23.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [23.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [22.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [22.0]},
#  {'dimensions': [{'name': '2024-08-11'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [21.0]},
#  {'dimensions': [{'name': '2024-08-12'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [21.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [21.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [21.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [21.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [21.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [21.0]},
#  {'dimensions': [{'name': '2024-08-01'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [20.0]},
#  {'dimensions': [{'name': '2024-08-11'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [20.0]},
#  {'dimensions': [{'name': '2024-08-19'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [20.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [20.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [20.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [20.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [20.0]},
#  {'dimensions': [{'name': '2024-08-06'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-08-08'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-08-12'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-08-13'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-08-14'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-08-15'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [19.0]},
#  {'dimensions': [{'name': '2024-08-02'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [18.0]},
#  {'dimensions': [{'name': '2024-08-08'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [18.0]},
#  {'dimensions': [{'name': '2024-08-13'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [18.0]},
#  {'dimensions': [{'name': '2024-08-15'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [18.0]},
#  {'dimensions': [{'name': '2024-08-19'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [18.0]},
#  {'dimensions': [{'name': '2024-08-19'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [18.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [18.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [18.0]},
#  {'dimensions': [{'name': '2024-08-06'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [17.0]},
#  {'dimensions': [{'name': '2024-08-07'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [17.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [17.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [17.0]},
#  {'dimensions': [{'name': '2024-08-16'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [16.0]},
#  {'dimensions': [{'name': '2024-08-16'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [16.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [16.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [16.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [16.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [16.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [16.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [16.0]},
#  {'dimensions': [{'name': '2024-08-21'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [15.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [15.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [15.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [15.0]},
#  {'dimensions': [{'name': '2024-08-04'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-08-07'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-08-15'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-08-20'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '212',
#     'icon_type': 'browser',
#     'name': 'YandexBrowserCorp',
#     'id': '212'}],
#   'metrics': [14.0]},
#  {'dimensions': [{'name': '2024-08-03'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-08'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-08'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-12'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-12'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-18'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-19'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-26'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [13.0]},
#  {'dimensions': [{'name': '2024-08-06'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-06'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-06'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-09'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-10'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-13'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-16'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-21'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-09-08'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [12.0]},
#  {'dimensions': [{'name': '2024-08-01'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-14'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-14'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-19'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-20'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-21'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-25'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-25'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [11.0]},
#  {'dimensions': [{'name': '2024-08-02'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-05'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-09'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-10'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-11'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-13'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-20'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-27'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-31'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '4', 'icon_type': 'browser', 'name': 'Safari', 'id': '4'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-08'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [10.0]},
#  {'dimensions': [{'name': '2024-08-01'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-01'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-02'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-05'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-05'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-06'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-07'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-07'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-09'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-10'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-16'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-17'},
#    {'icon_id': '70',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер',
#     'id': '70'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-25'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-27'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-08-31'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '38',
#     'icon_type': 'browser',
#     'name': 'Mobile Safari',
#     'id': '38'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '117',
#     'icon_type': 'browser',
#     'name': 'Яндекс Старт: мобильное приложение',
#     'id': '117'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '72',
#     'icon_type': 'browser',
#     'name': 'Android Browser',
#     'id': '72'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [9.0]},
#  {'dimensions': [{'name': '2024-09-16'},
# ...
#    {'icon_id': '14', 'icon_type': 'browser', 'name': 'UCWEB', 'id': '14'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-22'},
#    {'icon_id': '204',
#     'icon_type': 'browser',
#     'name': 'HeadlessChrome',
#     'id': '204'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-23'},
#    {'icon_id': '190',
#     'icon_type': 'browser',
#     'name': 'Samsung Internet',
#     'id': '190'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '2', 'icon_type': 'browser', 'name': 'Opera', 'id': '2'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '191', 'icon_type': 'browser', 'name': 'MIUI', 'id': '191'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-24'},
#    {'icon_id': '200',
#     'icon_type': 'browser',
#     'name': 'Opera Touch',
#     'id': '200'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-25'},
#    {'icon_id': '88',
#     'icon_type': 'browser',
#     'name': 'MQQBrowser',
#     'id': '88'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-25'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-25'},
#    {'icon_id': '199', 'icon_type': 'browser', 'name': 'Atom', 'id': '199'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-26'},
#    {'icon_id': '2', 'icon_type': 'browser', 'name': 'Opera', 'id': '2'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-26'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-27'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-27'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '203',
#     'icon_type': 'browser',
#     'name': 'Huawei Browser',
#     'id': '203'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-28'},
#    {'icon_id': '204',
#     'icon_type': 'browser',
#     'name': 'HeadlessChrome',
#     'id': '204'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '37',
#     'icon_type': 'browser',
#     'name': 'Opera Mobile',
#     'id': '37'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '192',
#     'icon_type': 'browser',
#     'name': 'Яндекс.Браузер lite',
#     'id': '192'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '200',
#     'icon_type': 'browser',
#     'name': 'Opera Touch',
#     'id': '200'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-29'},
#    {'icon_id': '212',
#     'icon_type': 'browser',
#     'name': 'YandexBrowserCorp',
#     'id': '212'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-30'},
#    {'icon_id': '190',
#     'icon_type': 'browser',
#     'name': 'Samsung Internet',
#     'id': '190'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-31'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-08-31'},
#    {'icon_id': '37',
#     'icon_type': 'browser',
#     'name': 'Opera Mobile',
#     'id': '37'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '3', 'icon_type': 'browser', 'name': 'Firefox', 'id': '3'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '37',
#     'icon_type': 'browser',
#     'name': 'Opera Mobile',
#     'id': '37'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '53',
#     'icon_type': 'browser',
#     'name': 'Firefox Mobile',
#     'id': '53'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '204',
#     'icon_type': 'browser',
#     'name': 'HeadlessChrome',
#     'id': '204'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-01'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '190',
#     'icon_type': 'browser',
#     'name': 'Samsung Internet',
#     'id': '190'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '203',
#     'icon_type': 'browser',
#     'name': 'Huawei Browser',
#     'id': '203'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-02'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '2', 'icon_type': 'browser', 'name': 'Opera', 'id': '2'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-03'},
#    {'icon_id': '212',
#     'icon_type': 'browser',
#     'name': 'YandexBrowserCorp',
#     'id': '212'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-04'},
#    {'icon_id': '204',
#     'icon_type': 'browser',
#     'name': 'HeadlessChrome',
#     'id': '204'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '37',
#     'icon_type': 'browser',
#     'name': 'Opera Mobile',
#     'id': '37'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '203',
#     'icon_type': 'browser',
#     'name': 'Huawei Browser',
#     'id': '203'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-05'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-06'},
#    {'icon_id': '191', 'icon_type': 'browser', 'name': 'MIUI', 'id': '191'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '53',
#     'icon_type': 'browser',
#     'name': 'Firefox Mobile',
#     'id': '53'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '88',
#     'icon_type': 'browser',
#     'name': 'MQQBrowser',
#     'id': '88'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '190',
#     'icon_type': 'browser',
#     'name': 'Samsung Internet',
#     'id': '190'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-07'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-08'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-08'},
#    {'icon_id': '203',
#     'icon_type': 'browser',
#     'name': 'Huawei Browser',
#     'id': '203'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '200',
#     'icon_type': 'browser',
#     'name': 'Opera Touch',
#     'id': '200'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-09'},
#    {'icon_id': '212',
#     'icon_type': 'browser',
#     'name': 'YandexBrowserCorp',
#     'id': '212'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '14', 'icon_type': 'browser', 'name': 'UCWEB', 'id': '14'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '53',
#     'icon_type': 'browser',
#     'name': 'Firefox Mobile',
#     'id': '53'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-10'},
#    {'icon_id': '203',
#     'icon_type': 'browser',
#     'name': 'Huawei Browser',
#     'id': '203'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '37',
#     'icon_type': 'browser',
#     'name': 'Opera Mobile',
#     'id': '37'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-11'},
#    {'icon_id': '190',
#     'icon_type': 'browser',
#     'name': 'Samsung Internet',
#     'id': '190'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '14', 'icon_type': 'browser', 'name': 'UCWEB', 'id': '14'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '117',
#     'icon_type': 'browser',
#     'name': 'Яндекс Старт: мобильное приложение',
#     'id': '117'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-12'},
#    {'icon_id': '191', 'icon_type': 'browser', 'name': 'MIUI', 'id': '191'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '30',
#     'icon_type': 'browser',
#     'name': 'WebKit, другие',
#     'id': '30'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '37',
#     'icon_type': 'browser',
#     'name': 'Opera Mobile',
#     'id': '37'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '53',
#     'icon_type': 'browser',
#     'name': 'Firefox Mobile',
#     'id': '53'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '191', 'icon_type': 'browser', 'name': 'MIUI', 'id': '191'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '203',
#     'icon_type': 'browser',
#     'name': 'Huawei Browser',
#     'id': '203'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-13'},
#    {'icon_id': '217', 'icon_type': 'browser', 'name': 'Phoenix', 'id': '217'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '2', 'icon_type': 'browser', 'name': 'Opera', 'id': '2'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '53',
#     'icon_type': 'browser',
#     'name': 'Firefox Mobile',
#     'id': '53'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-14'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '1', 'icon_type': 'browser', 'name': 'Opera Mini', 'id': '1'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '14', 'icon_type': 'browser', 'name': 'UCWEB', 'id': '14'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '120',
#     'icon_type': 'browser',
#     'name': 'Google: мобильное приложение',
#     'id': '120'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '135', 'icon_type': 'browser', 'name': 'Edge', 'id': '135'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-15'},
#    {'icon_id': '203',
#     'icon_type': 'browser',
#     'name': 'Huawei Browser',
#     'id': '203'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '14', 'icon_type': 'browser', 'name': 'UCWEB', 'id': '14'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '204',
#     'icon_type': 'browser',
#     'name': 'HeadlessChrome',
#     'id': '204'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-16'},
#    {'icon_id': '217', 'icon_type': 'browser', 'name': 'Phoenix', 'id': '217'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '0', 'icon_type': 'browser', 'name': None, 'id': '0'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '117',
#     'icon_type': 'browser',
#     'name': 'Яндекс Старт: мобильное приложение',
#     'id': '117'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-17'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '14', 'icon_type': 'browser', 'name': 'UCWEB', 'id': '14'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '37',
#     'icon_type': 'browser',
#     'name': 'Opera Mobile',
#     'id': '37'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '150', 'icon_type': 'browser', 'name': 'WeChat', 'id': '150'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '191', 'icon_type': 'browser', 'name': 'MIUI', 'id': '191'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '205',
#     'icon_type': 'browser',
#     'name': 'Яндекс с Алисой: мобильное приложение',
#     'id': '205'}],
#   'metrics': [1.0]},
#  {'dimensions': [{'name': '2024-09-18'},
#    {'icon_id': '212',
#     'icon_type': 'browser',
#     'name': 'YandexBrowserCorp',
#     'id': '212'}],
#   'metrics': [1.0]}]

# %%
m.reformat_api_report()
m.report_formatted
# Out:
# [['2024-08-07', 'Google Chrome', 225.0],
#  ['2024-09-03', 'Google Chrome', 225.0],
#  ['2024-09-17', 'Google Chrome', 221.0],
#  ['2024-09-11', 'Google Chrome', 217.0],
#  ['2024-09-06', 'Google Chrome', 216.0],
#  ['2024-09-10', 'Google Chrome', 213.0],
#  ['2024-08-20', 'Google Chrome', 209.0],
#  ['2024-08-05', 'Google Chrome', 208.0],
#  ['2024-09-09', 'Google Chrome', 206.0],
#  ['2024-09-16', 'Google Chrome', 201.0],
#  ['2024-08-12', 'Google Chrome', 200.0],
#  ['2024-08-26', 'Google Chrome', 200.0],
#  ['2024-08-06', 'Google Chrome', 199.0],
#  ['2024-08-21', 'Google Chrome', 199.0],
#  ['2024-09-04', 'Google Chrome', 199.0],
#  ['2024-08-22', 'Google Chrome', 196.0],
#  ['2024-08-13', 'Google Chrome', 194.0],
#  ['2024-09-13', 'Google Chrome', 191.0],
#  ['2024-08-08', 'Google Chrome', 187.0],
#  ['2024-09-05', 'Google Chrome', 187.0],
#  ['2024-08-27', 'Google Chrome', 185.0],
#  ['2024-08-14', 'Google Chrome', 183.0],
#  ['2024-08-29', 'Google Chrome', 179.0],
#  ['2024-09-18', 'Google Chrome', 179.0],
#  ['2024-09-12', 'Google Chrome', 178.0],
#  ['2024-08-19', 'Google Chrome', 170.0],
#  ['2024-08-23', 'Google Chrome', 167.0],
#  ['2024-08-15', 'Google Chrome', 163.0],
#  ['2024-08-28', 'Google Chrome', 163.0],
#  ['2024-08-30', 'Google Chrome', 163.0],
#  ['2024-09-02', 'Google Chrome', 163.0],
#  ['2024-08-16', 'Google Chrome', 147.0],
#  ['2024-08-09', 'Google Chrome', 136.0],
#  ['2024-08-11', 'Google Chrome', 124.0],
#  ['2024-08-10', 'Google Chrome', 120.0],
#  ['2024-08-03', 'Chrome Mobile', 116.0],
#  ['2024-08-02', 'Google Chrome', 111.0],
#  ['2024-08-01', 'Google Chrome', 108.0],
#  ['2024-08-05', 'Chrome Mobile', 104.0],
#  ['2024-08-08', 'Chrome Mobile', 104.0],
#  ['2024-08-01', 'Chrome Mobile', 102.0],
#  ['2024-08-18', 'Google Chrome', 100.0],
#  ['2024-09-13', 'Chrome Mobile', 100.0],
#  ['2024-08-02', 'Chrome Mobile', 99.0],
#  ['2024-08-06', 'Chrome Mobile', 98.0],
#  ['2024-08-09', 'Chrome Mobile', 98.0],
#  ['2024-08-03', 'Google Chrome', 95.0],
#  ['2024-08-12', 'Chrome Mobile', 95.0],
#  ['2024-09-15', 'Google Chrome', 95.0],
#  ['2024-08-24', 'Google Chrome', 93.0],
#  ['2024-08-25', 'Google Chrome', 93.0],
#  ['2024-08-04', 'Google Chrome', 92.0],
#  ['2024-08-11', 'Chrome Mobile', 92.0],
#  ['2024-08-04', 'Chrome Mobile', 91.0],
#  ['2024-09-01', 'Google Chrome', 91.0],
#  ['2024-08-14', 'Chrome Mobile', 90.0],
#  ['2024-09-07', 'Google Chrome', 88.0],
#  ['2024-08-15', 'Chrome Mobile', 87.0],
#  ['2024-09-14', 'Google Chrome', 86.0],
#  ['2024-09-04', 'Chrome Mobile', 85.0],
#  ['2024-09-07', 'Chrome Mobile', 85.0],
#  ['2024-09-11', 'Chrome Mobile', 84.0],
#  ['2024-08-13', 'Chrome Mobile', 83.0],
#  ['2024-08-30', 'Chrome Mobile', 83.0],
#  ['2024-08-16', 'Chrome Mobile', 82.0],
#  ['2024-09-05', 'Chrome Mobile', 82.0],
#  ['2024-09-08', 'Google Chrome', 82.0],
#  ['2024-08-17', 'Google Chrome', 81.0],
#  ['2024-08-21', 'Chrome Mobile', 81.0],
#  ['2024-09-14', 'Chrome Mobile', 81.0],
#  ['2024-08-31', 'Google Chrome', 80.0],
#  ['2024-08-07', 'Chrome Mobile', 79.0],
#  ['2024-08-20', 'Chrome Mobile', 78.0],
#  ['2024-09-12', 'Chrome Mobile', 78.0],
#  ['2024-08-28', 'Chrome Mobile', 77.0],
#  ['2024-09-03', 'Chrome Mobile', 77.0],
#  ['2024-08-10', 'Chrome Mobile', 75.0],
#  ['2024-08-24', 'Chrome Mobile', 74.0],
#  ['2024-09-17', 'Chrome Mobile', 73.0],
#  ['2024-08-26', 'Chrome Mobile', 72.0],
#  ['2024-08-19', 'Chrome Mobile', 71.0],
#  ['2024-08-29', 'Chrome Mobile', 71.0],
#  ['2024-09-06', 'Chrome Mobile', 71.0],
#  ['2024-09-09', 'Chrome Mobile', 69.0],
#  ['2024-09-15', 'Chrome Mobile', 68.0],
#  ['2024-09-16', 'Chrome Mobile', 68.0],
#  ['2024-09-01', 'Chrome Mobile', 66.0],
#  ['2024-09-02', 'Chrome Mobile', 66.0],
#  ['2024-08-18', 'Chrome Mobile', 65.0],
#  ['2024-08-23', 'Chrome Mobile', 65.0],
#  ['2024-09-08', 'Chrome Mobile', 65.0],
#  ['2024-08-22', 'Chrome Mobile', 63.0],
#  ['2024-08-31', 'Chrome Mobile', 63.0],
#  ['2024-08-17', 'Chrome Mobile', 61.0],
#  ['2024-09-10', 'Chrome Mobile', 61.0],
#  ['2024-08-27', 'Chrome Mobile', 58.0],
#  ['2024-08-25', 'Chrome Mobile', 56.0],
#  ['2024-09-18', 'Chrome Mobile', 51.0],
#  ['2024-08-30', 'Яндекс.Браузер', 44.0],
#  ['2024-09-05', 'Яндекс.Браузер', 40.0],
#  ['2024-08-02', 'Яндекс.Браузер', 37.0],
#  ['2024-08-20', 'Яндекс.Браузер', 37.0],
#  ['2024-08-12', 'Яндекс.Браузер', 34.0],
#  ['2024-08-29', 'Яндекс.Браузер', 33.0],
#  ['2024-09-16', 'Яндекс.Браузер', 32.0],
#  ['2024-08-09', 'Яндекс.Браузер', 31.0],
#  ['2024-08-22', 'Яндекс.Браузер', 31.0],
#  ['2024-08-26', 'Edge', 31.0],
#  ['2024-08-05', 'Safari', 30.0],
#  ['2024-09-17', 'Яндекс.Браузер', 30.0],
#  ['2024-08-21', 'Яндекс.Браузер', 29.0],
#  ['2024-09-12', 'Яндекс.Браузер', 29.0],
#  ['2024-08-14', 'Яндекс.Браузер', 28.0],
#  ['2024-08-27', 'Яндекс.Браузер', 28.0],
#  ['2024-09-02', 'Яндекс.Браузер', 28.0],
#  ['2024-09-04', 'Яндекс.Браузер', 28.0],
#  ['2024-08-07', 'Яндекс.Браузер', 27.0],
#  ['2024-08-21', 'Safari', 27.0],
#  ['2024-09-03', 'Яндекс.Браузер', 27.0],
#  ['2024-09-09', 'Яндекс.Браузер', 27.0],
#  ['2024-09-10', 'Яндекс.Браузер', 27.0],
#  ['2024-08-13', 'Яндекс.Браузер', 26.0],
#  ['2024-09-05', 'Safari', 26.0],
#  ['2024-08-15', 'Яндекс.Браузер', 25.0],
#  ['2024-08-27', 'Safari', 25.0],
#  ['2024-08-31', 'Яндекс.Браузер', 25.0],
#  ['2024-09-13', 'Safari', 25.0],
#  ['2024-09-13', 'Яндекс.Браузер', 25.0],
#  ['2024-08-05', 'Яндекс.Браузер', 24.0],
#  ['2024-08-09', 'Safari', 24.0],
#  ['2024-08-16', 'Яндекс.Браузер', 24.0],
#  ['2024-09-04', 'Safari', 24.0],
#  ['2024-09-10', 'Safari', 24.0],
#  ['2024-08-08', 'Яндекс.Браузер', 23.0],
#  ['2024-08-26', 'Яндекс.Браузер', 23.0],
#  ['2024-08-28', 'Safari', 23.0],
#  ['2024-09-18', 'Яндекс.Браузер', 23.0],
#  ['2024-09-11', 'Android Browser', 22.0],
#  ['2024-09-12', 'Safari', 22.0],
#  ['2024-08-11', 'Mobile Safari', 21.0],
#  ['2024-08-12', 'Mobile Safari', 21.0],
#  ['2024-08-28', 'Яндекс.Браузер', 21.0],
#  ['2024-09-01', 'Яндекс.Браузер', 21.0],
#  ['2024-09-06', 'Safari', 21.0],
#  ['2024-09-06', 'Яндекс.Браузер', 21.0],
#  ['2024-09-18', 'Safari', 21.0],
#  ['2024-08-01', 'Яндекс.Браузер', 20.0],
#  ['2024-08-11', 'Яндекс.Браузер', 20.0],
#  ['2024-08-19', 'Mobile Safari', 20.0],
#  ['2024-09-11', 'Safari', 20.0],
#  ['2024-09-11', 'Яндекс.Браузер', 20.0],
#  ['2024-09-13', 'Android Browser', 20.0],
#  ['2024-09-17', 'Safari', 20.0],
#  ['2024-08-06', 'Яндекс.Браузер', 19.0],
#  ['2024-08-08', 'Mobile Safari', 19.0],
#  ['2024-08-12', 'Safari', 19.0],
#  ['2024-08-13', 'Safari', 19.0],
#  ['2024-08-14', 'Safari', 19.0],
#  ['2024-08-15', 'Safari', 19.0],
#  ['2024-08-23', 'Яндекс.Браузер', 19.0],
#  ['2024-09-02', 'Safari', 19.0],
#  ['2024-09-03', 'Safari', 19.0],
#  ['2024-08-02', 'Edge', 18.0],
#  ['2024-08-08', 'Safari', 18.0],
#  ['2024-08-13', 'Mobile Safari', 18.0],
#  ['2024-08-15', 'Firefox', 18.0],
#  ['2024-08-19', 'Safari', 18.0],
#  ['2024-08-19', 'Яндекс.Браузер', 18.0],
#  ['2024-09-03', 'Firefox', 18.0],
#  ['2024-09-09', 'Safari', 18.0],
#  ['2024-08-06', 'Mobile Safari', 17.0],
#  ['2024-08-07', 'Safari', 17.0],
#  ['2024-09-06', 'Firefox', 17.0],
#  ['2024-09-15', 'Яндекс.Браузер', 17.0],
#  ['2024-08-16', 'Firefox', 16.0],
#  ['2024-08-16', 'Safari', 16.0],
#  ['2024-08-30', 'Firefox', 16.0],
#  ['2024-09-07', 'Яндекс.Браузер', 16.0],
#  ['2024-09-11', 'Edge', 16.0],
#  ['2024-09-16', 'Safari', 16.0],
#  ['2024-09-16', 'Edge', 16.0],
#  ['2024-09-17', 'Edge', 16.0],
#  ['2024-08-21', 'Android Browser', 15.0],
#  ['2024-08-22', 'Edge', 15.0],
#  ['2024-08-23', 'Safari', 15.0],
#  ['2024-09-03', 'Mobile Safari', 15.0],
#  ['2024-08-04', 'Яндекс.Браузер', 14.0],
#  ['2024-08-07', 'Edge', 14.0],
#  ['2024-08-15', 'Edge', 14.0],
#  ['2024-08-20', 'Safari', 14.0],
#  ['2024-08-22', 'Firefox', 14.0],
#  ['2024-09-02', 'Firefox', 14.0],
#  ['2024-09-02', 'Mobile Safari', 14.0],
#  ['2024-09-09', 'Mobile Safari', 14.0],
#  ['2024-09-15', 'Android Browser', 14.0],
#  ['2024-09-16', 'YandexBrowserCorp', 14.0],
#  ['2024-08-03', 'Яндекс.Браузер', 13.0],
#  ['2024-08-08', 'Firefox', 13.0],
#  ['2024-08-08', 'Edge', 13.0],
#  ['2024-08-12', 'Firefox', 13.0],
#  ['2024-08-12', 'Edge', 13.0],
#  ['2024-08-18', 'Яндекс.Браузер', 13.0],
#  ['2024-08-19', 'Edge', 13.0],
#  ['2024-08-23', 'Mobile Safari', 13.0],
#  ['2024-08-26', 'Safari', 13.0],
#  ['2024-08-29', 'Safari', 13.0],
#  ['2024-09-03', 'Edge', 13.0],
#  ['2024-09-09', 'Edge', 13.0],
#  ['2024-09-10', 'Mobile Safari', 13.0],
#  ['2024-09-16', 'Mobile Safari', 13.0],
#  ['2024-09-17', 'Firefox', 13.0],
#  ['2024-08-06', 'Firefox', 12.0],
#  ['2024-08-06', 'Safari', 12.0],
#  ['2024-08-06', 'Edge', 12.0],
#  ['2024-08-09', 'Edge', 12.0],
#  ['2024-08-10', 'Safari', 12.0],
#  ['2024-08-13', 'Firefox', 12.0],
#  ['2024-08-16', 'Mobile Safari', 12.0],
#  ['2024-08-21', 'Firefox', 12.0],
#  ['2024-08-22', 'Safari', 12.0],
#  ['2024-08-22', 'Mobile Safari', 12.0],
#  ['2024-08-24', 'Яндекс.Браузер', 12.0],
#  ['2024-08-29', 'Edge', 12.0],
#  ['2024-08-30', 'Safari', 12.0],
#  ['2024-08-30', 'Mobile Safari', 12.0],
#  ['2024-09-02', 'Edge', 12.0],
#  ['2024-09-05', 'Edge', 12.0],
#  ['2024-09-07', 'Safari', 12.0],
#  ['2024-09-08', 'Яндекс.Браузер', 12.0],
#  ['2024-09-14', 'Яндекс.Браузер', 12.0],
#  ['2024-09-15', 'Safari', 12.0],
#  ['2024-08-01', 'Mobile Safari', 11.0],
#  ['2024-08-14', 'Firefox', 11.0],
#  ['2024-08-14', 'Edge', 11.0],
#  ['2024-08-19', 'Firefox', 11.0],
#  ['2024-08-20', 'Edge', 11.0],
#  ['2024-08-21', 'Edge', 11.0],
#  ['2024-08-24', 'Mobile Safari', 11.0],
#  ['2024-08-25', 'Safari', 11.0],
#  ['2024-08-25', 'Mobile Safari', 11.0],
#  ['2024-08-28', 'Mobile Safari', 11.0],
#  ['2024-08-29', 'Firefox', 11.0],
#  ['2024-08-29', 'Mobile Safari', 11.0],
#  ['2024-09-04', 'Firefox', 11.0],
#  ['2024-09-04', 'Mobile Safari', 11.0],
#  ['2024-09-04', 'Edge', 11.0],
#  ['2024-09-07', 'Edge', 11.0],
#  ['2024-09-10', 'Android Browser', 11.0],
#  ['2024-09-13', 'Mobile Safari', 11.0],
#  ['2024-09-13', 'Edge', 11.0],
#  ['2024-09-18', 'Mobile Safari', 11.0],
#  ['2024-08-02', 'Firefox', 10.0],
#  ['2024-08-05', 'Mobile Safari', 10.0],
#  ['2024-08-09', 'Mobile Safari', 10.0],
#  ['2024-08-10', 'Mobile Safari', 10.0],
#  ['2024-08-11', 'Safari', 10.0],
#  ['2024-08-13', 'Edge', 10.0],
#  ['2024-08-20', 'Mobile Safari', 10.0],
#  ['2024-08-23', 'Firefox', 10.0],
#  ['2024-08-23', 'Edge', 10.0],
#  ['2024-08-24', 'Edge', 10.0],
#  ['2024-08-27', 'Firefox', 10.0],
#  ['2024-08-28', 'Firefox', 10.0],
#  ['2024-08-31', 'Safari', 10.0],
#  ['2024-09-01', 'Safari', 10.0],
#  ['2024-09-01', 'Mobile Safari', 10.0],
#  ['2024-09-06', 'Edge', 10.0],
#  ['2024-09-08', 'Android Browser', 10.0],
#  ['2024-09-09', 'Firefox', 10.0],
#  ['2024-09-12', 'Mobile Safari', 10.0],
#  ['2024-09-12', 'Android Browser', 10.0],
#  ['2024-09-12', 'Edge', 10.0],
#  ['2024-09-14', 'Mobile Safari', 10.0],
#  ['2024-09-17', 'Mobile Safari', 10.0],
#  ['2024-08-01', 'Firefox', 9.0],
#  ['2024-08-01', 'Edge', 9.0],
#  ['2024-08-02', 'Mobile Safari', 9.0],
#  ['2024-08-05', 'Firefox', 9.0],
#  ['2024-08-05', 'Edge', 9.0],
#  ['2024-08-06', 'Android Browser', 9.0],
#  ['2024-08-07', 'Firefox', 9.0],
#  ['2024-08-07', 'Mobile Safari', 9.0],
#  ['2024-08-09', 'Firefox', 9.0],
#  ['2024-08-10', 'Яндекс.Браузер', 9.0],
#  ['2024-08-16', 'Edge', 9.0],
#  ['2024-08-17', 'Яндекс.Браузер', 9.0],
#  ['2024-08-24', 'Firefox', 9.0],
#  ['2024-08-25', 'Edge', 9.0],
#  ['2024-08-27', 'Mobile Safari', 9.0],
#  ['2024-08-30', 'Edge', 9.0],
#  ['2024-08-31', 'Edge', 9.0],
#  ['2024-09-07', 'Mobile Safari', 9.0],
#  ['2024-09-07', 'Яндекс Старт: мобильное приложение', 9.0],
#  ['2024-09-09', 'Android Browser', 9.0],
#  ['2024-09-10', 'Firefox', 9.0],
#  ['2024-09-14', 'Firefox', 9.0],
#  ['2024-09-16', 'Firefox', 9.0],
#  ['2024-08-04', 'Mobile Safari', 8.0],
#  ['2024-08-08', 'Android Browser', 8.0],
#  ['2024-08-10', 'Samsung Internet', 8.0],
#  ['2024-08-14', 'Mobile Safari', 8.0],
#  ['2024-08-15', 'Mobile Safari', 8.0],
#  ['2024-08-17', 'Mobile Safari', 8.0],
#  ['2024-08-18', 'Safari', 8.0],
#  ['2024-08-21', 'Mobile Safari', 8.0],
#  ['2024-08-24', 'Safari', 8.0],
#  ['2024-08-25', 'Firefox', 8.0],
#  ['2024-08-25', 'Яндекс.Браузер', 8.0],
#  ['2024-08-28', 'Edge', 8.0],
#  ['2024-08-30', 'Android Browser', 8.0],
#  ['2024-08-31', 'Firefox', 8.0],
#  ['2024-08-31', 'Яндекс Старт: мобильное приложение', 8.0],
#  ['2024-09-03', 'Android Browser', 8.0],
#  ['2024-09-05', 'Firefox', 8.0],
#  ['2024-09-06', 'Mobile Safari', 8.0],
#  ['2024-09-08', 'Edge', 8.0],
#  ['2024-09-10', 'Edge', 8.0],
#  ['2024-09-11', 'Opera', 8.0],
#  ['2024-09-11', 'Mobile Safari', 8.0],
#  ['2024-09-12', 'Firefox', 8.0],
#  ['2024-09-13', 'Firefox', 8.0],
#  ['2024-09-17', 'Android Browser', 8.0],
#  ['2024-09-18', 'Android Browser', 8.0],
#  ['2024-09-18', 'Edge', 8.0],
#  ['2024-08-01', 'Safari', 7.0],
#  ['2024-08-05', 'Android Browser', 7.0],
#  ['2024-08-07', 'Opera', 7.0],
#  ['2024-08-07', 'Android Browser', 7.0],
#  ['2024-08-17', 'Safari', 7.0],
#  ['2024-08-27', 'Edge', 7.0],
#  ['2024-08-29', 'Android Browser', 7.0],
#  ['2024-08-31', 'Mobile Safari', 7.0],
#  ['2024-09-06', 'Opera', 7.0],
#  ['2024-09-08', 'Firefox', 7.0],
#  ['2024-09-08', 'Mobile Safari', 7.0],
#  ['2024-09-14', 'Safari', 7.0],
#  ['2024-09-14', 'Android Browser', 7.0],
#  ['2024-09-14', 'Яндекс Старт: мобильное приложение', 7.0],
#  ['2024-09-15', 'Mobile Safari', 7.0],
#  ['2024-09-15', 'Яндекс Старт: мобильное приложение', 7.0],
#  ['2024-08-02', 'Samsung Internet', 6.0],
#  ['2024-08-03', 'Mobile Safari', 6.0],
#  ['2024-08-03', 'Edge', 6.0],
#  ['2024-08-08', 'Opera', 6.0],
#  ['2024-08-09', 'Яндекс Старт: мобильное приложение', 6.0],
#  ['2024-08-10', 'Edge', 6.0],
#  ['2024-08-12', 'Opera', 6.0],
#  ['2024-08-16', 'Opera', 6.0],
#  ['2024-08-16', 'Android Browser', 6.0],
#  ['2024-08-17', 'Firefox', 6.0],
#  ['2024-08-17', 'Android Browser', 6.0],
#  ['2024-08-17', 'Edge', 6.0],
#  ['2024-08-19', 'Opera', 6.0],
#  ['2024-08-19', 'Android Browser', 6.0],
#  ['2024-08-20', 'Firefox', 6.0],
#  ['2024-08-20', 'Android Browser', 6.0],
#  ['2024-08-23', 'Android Browser', 6.0],
#  ['2024-08-26', 'Firefox', 6.0],
#  ['2024-08-26', 'Mobile Safari', 6.0],
#  ['2024-08-28', 'Яндекс Старт: мобильное приложение', 6.0],
#  ['2024-09-01', 'Яндекс Старт: мобильное приложение', 6.0],
#  ['2024-09-01', 'Edge', 6.0],
#  ['2024-09-02', 'Яндекс Старт: мобильное приложение', 6.0],
#  ['2024-09-05', 'Mobile Safari', 6.0],
#  ['2024-09-06', 'Android Browser', 6.0],
#  ['2024-09-07', 'Firefox', 6.0],
#  ['2024-09-08', 'Safari', 6.0],
#  ['2024-09-09', 'Samsung Internet', 6.0],
#  ['2024-09-11', 'Firefox', 6.0],
#  ['2024-09-13', 'Opera', 6.0],
#  ['2024-09-13', 'Яндекс Старт: мобильное приложение', 6.0],
#  ['2024-09-14', 'Edge', 6.0],
#  ['2024-09-15', 'Opera', 6.0],
#  ['2024-09-16', 'Opera', 6.0],
#  ['2024-09-18', 'Samsung Internet', 6.0],
#  ['2024-08-01', 'Android Browser', 5.0],
#  ['2024-08-03', 'Android Browser', 5.0],
#  ['2024-08-04', 'Яндекс Старт: мобильное приложение', 5.0],
#  ['2024-08-06', 'Samsung Internet', 5.0],
#  ['2024-08-10', 'Firefox', 5.0],
#  ['2024-08-10', 'Android Browser', 5.0],
#  ['2024-08-11', 'Firefox', 5.0],
#  ['2024-08-11', 'Android Browser', 5.0],
#  ['2024-08-12', 'Android Browser', 5.0],
#  ['2024-08-13', 'Opera', 5.0],
#  ['2024-08-13', 'Яндекс Старт: мобильное приложение', 5.0],
#  ['2024-08-16', 'Яндекс Старт: мобильное приложение', 5.0],
#  ['2024-08-18', 'Opera', 5.0],
#  ['2024-08-18', 'Mobile Safari', 5.0],
#  ['2024-08-18', 'Edge', 5.0],
#  ['2024-08-22', 'Android Browser', 5.0],
#  ['2024-08-22', 'Samsung Internet', 5.0],
#  ['2024-08-25', 'Яндекс Старт: мобильное приложение', 5.0],
#  ['2024-08-26', 'Яндекс Старт: мобильное приложение', 5.0],
#  ['2024-08-28', 'Opera', 5.0],
#  ['2024-08-28', 'Samsung Internet', 5.0],
#  ['2024-08-29', 'Opera', 5.0],
#  ['2024-08-31', 'Samsung Internet', 5.0],
#  ['2024-09-01', 'Android Browser', 5.0],
#  ['2024-09-04', 'Android Browser', 5.0],
#  ['2024-09-05', 'Opera', 5.0],
#  ['2024-09-08', 'Samsung Internet', 5.0],
#  ['2024-09-16', 'Яндекс Старт: мобильное приложение', 5.0],
#  ['2024-09-18', 'Firefox', 5.0],
#  ['2024-08-02', 'Android Browser', 4.0],
#  ['2024-08-02', 'Яндекс Старт: мобильное приложение', 4.0],
#  ['2024-08-03', 'Firefox', 4.0],
#  ['2024-08-03', 'Safari', 4.0],
#  ['2024-08-03', 'Samsung Internet', 4.0],
#  ['2024-08-04', 'Android Browser', 4.0],
#  ['2024-08-09', 'Opera', 4.0],
#  ['2024-08-16', 'Samsung Internet', 4.0],
#  ['2024-08-17', 'Opera', 4.0],
#  ['2024-08-18', 'Android Browser', 4.0],
#  ['2024-08-20', 'Firefox Mobile', 4.0],
#  ['2024-08-21', 'Opera', 4.0],
#  ['2024-08-23', 'Opera', 4.0],
#  ['2024-08-24', 'Яндекс Старт: мобильное приложение', 4.0],
#  ['2024-08-26', 'Android Browser', 4.0],
#  ['2024-08-27', 'Яндекс Старт: мобильное приложение', 4.0],
#  ['2024-08-27', 'Samsung Internet', 4.0],
#  ['2024-08-28', 'Android Browser', 4.0],
#  ['2024-08-30', 'Opera', 4.0],
#  ['2024-08-30', 'Яндекс Старт: мобильное приложение', 4.0],
#  ['2024-09-02', 'Android Browser', 4.0],
#  ['2024-09-03', 'Яндекс Старт: мобильное приложение', 4.0],
#  ['2024-09-05', 'Яндекс Старт: мобильное приложение', 4.0],
#  ['2024-09-06', 'Яндекс Старт: мобильное приложение', 4.0],
#  ['2024-09-06', 'Samsung Internet', 4.0],
#  ['2024-09-07', 'Android Browser', 4.0],
#  ['2024-09-10', 'Яндекс Старт: мобильное приложение', 4.0],
#  ['2024-09-12', 'Opera', 4.0],
#  ['2024-09-15', 'Samsung Internet', 4.0],
#  ['2024-09-18', 'HeadlessChrome', 4.0],
#  ['2024-08-01', 'Яндекс Старт: мобильное приложение', 3.0],
#  ['2024-08-01', 'Samsung Internet', 3.0],
#  ['2024-08-04', 'Opera', 3.0],
#  ['2024-08-04', 'Firefox', 3.0],
#  ['2024-08-05', 'Яндекс Старт: мобильное приложение', 3.0],
#  ['2024-08-05', 'YandexBrowserCorp', 3.0],
#  ['2024-08-07', 'Samsung Internet', 3.0],
#  ['2024-08-11', 'Opera', 3.0],
#  ['2024-08-11', 'Яндекс Старт: мобильное приложение', 3.0],
#  ['2024-08-12', 'Яндекс Старт: мобильное приложение', 3.0],
#  ['2024-08-13', 'Android Browser', 3.0],
#  ['2024-08-14', 'Opera', 3.0],
#  ['2024-08-14', 'Android Browser', 3.0],
#  ['2024-08-15', 'Samsung Internet', 3.0],
#  ['2024-08-18', 'Firefox', 3.0],
#  ['2024-08-18', 'Firefox Mobile', 3.0],
#  ['2024-08-18', 'Яндекс Старт: мобильное приложение', 3.0],
#  ['2024-08-19', None, 3.0],
#  ['2024-08-20', 'Opera', 3.0],
#  ['2024-08-22', 'Яндекс Старт: мобильное приложение', 3.0],
#  ['2024-08-24', 'Android Browser', 3.0],
#  ['2024-08-25', 'Android Browser', 3.0],
#  ['2024-08-25', 'Samsung Internet', 3.0],
#  ['2024-08-27', 'Opera', 3.0],
#  ['2024-08-29', 'Firefox Mobile', 3.0],
#  ['2024-08-29', 'Samsung Internet', 3.0],
#  ['2024-08-31', 'Opera', 3.0],
#  ['2024-09-04', 'Samsung Internet', 3.0],
#  ['2024-09-10', 'Opera', 3.0],
#  ['2024-09-11', 'Яндекс Старт: мобильное приложение', 3.0],
#  ['2024-09-12', 'Samsung Internet', 3.0],
#  ['2024-09-16', 'Android Browser', 3.0],
#  ['2024-09-17', 'Opera', 3.0],
#  ['2024-09-18', 'Яндекс Старт: мобильное приложение', 3.0],
#  ['2024-08-01', 'Opera', 2.0],
#  ['2024-08-01', 'Яндекс с Алисой: мобильное приложение', 2.0],
#  ['2024-08-02', None, 2.0],
#  ['2024-08-02', 'Safari', 2.0],
#  ['2024-08-03', None, 2.0],
#  ['2024-08-03', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-08-04', 'Edge', 2.0],
#  ['2024-08-04', 'Samsung Internet', 2.0],
#  ['2024-08-05', None, 2.0],
#  ['2024-08-05', 'Opera', 2.0],
#  ['2024-08-05', 'Opera Mobile', 2.0],
#  ['2024-08-06', None, 2.0],
#  ['2024-08-07', None, 2.0],
#  ['2024-08-08', 'Firefox Mobile', 2.0],
#  ['2024-08-08', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-08-08', 'Samsung Internet', 2.0],
#  ['2024-08-09', None, 2.0],
#  ['2024-08-09', 'Samsung Internet', 2.0],
#  ['2024-08-10', 'Opera', 2.0],
#  ['2024-08-10', 'Firefox Mobile', 2.0],
#  ['2024-08-10', 'MIUI', 2.0],
#  ['2024-08-11', None, 2.0],
#  ['2024-08-11', 'Samsung Internet', 2.0],
#  ['2024-08-13', None, 2.0],
#  ['2024-08-14', 'Firefox Mobile', 2.0],
#  ['2024-08-15', None, 2.0],
#  ['2024-08-15', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-08-16', None, 2.0],
#  ['2024-08-16', 'Яндекс.Браузер lite', 2.0],
#  ['2024-08-17', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-08-18', None, 2.0],
#  ['2024-08-18', 'Samsung Internet', 2.0],
#  ['2024-08-19', 'YandexBrowserCorp', 2.0],
#  ['2024-08-20', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-08-20', 'Samsung Internet', 2.0],
#  ['2024-08-21', 'Firefox Mobile', 2.0],
#  ['2024-08-21', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-08-22', 'YandexBrowserCorp', 2.0],
#  ['2024-08-23', 'Opera Mini', 2.0],
#  ['2024-08-23', 'MIUI', 2.0],
#  ['2024-08-24', None, 2.0],
#  ['2024-08-25', None, 2.0],
#  ['2024-08-26', None, 2.0],
#  ['2024-08-26', 'Samsung Internet', 2.0],
#  ['2024-08-26', 'YandexBrowserCorp', 2.0],
#  ['2024-08-27', 'Android Browser', 2.0],
#  ['2024-08-28', 'MIUI', 2.0],
#  ['2024-08-29', None, 2.0],
#  ['2024-08-29', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-08-30', 'Яндекс с Алисой: мобильное приложение', 2.0],
#  ['2024-08-31', 'Android Browser', 2.0],
#  ['2024-09-01', None, 2.0],
#  ['2024-09-01', 'Opera', 2.0],
#  ['2024-09-01', 'Samsung Internet', 2.0],
#  ['2024-09-01', 'YandexBrowserCorp', 2.0],
#  ['2024-09-02', 'Firefox Mobile', 2.0],
#  ['2024-09-03', 'Samsung Internet', 2.0],
#  ['2024-09-03', 'MIUI', 2.0],
#  ['2024-09-04', 'Opera', 2.0],
#  ['2024-09-04', 'Firefox Mobile', 2.0],
#  ['2024-09-04', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-09-05', None, 2.0],
#  ['2024-09-05', 'Android Browser', 2.0],
#  ['2024-09-05', 'Samsung Internet', 2.0],
#  ['2024-09-07', 'Opera', 2.0],
#  ['2024-09-08', 'Opera', 2.0],
#  ['2024-09-08', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-09-09', 'Opera', 2.0],
#  ['2024-09-09', 'Яндекс Старт: мобильное приложение', 2.0],
#  ['2024-09-09', 'Google: мобильное приложение', 2.0],
#  ['2024-09-10', None, 2.0],
#  ['2024-09-10', 'Samsung Internet', 2.0],
#  ['2024-09-13', 'Samsung Internet', 2.0],
#  ['2024-09-13', 'YandexBrowserCorp', 2.0],
#  ['2024-09-14', 'Opera Mobile', 2.0],
#  ['2024-09-14', 'Google: мобильное приложение', 2.0],
#  ['2024-09-14', 'Samsung Internet', 2.0],
#  ['2024-09-14', 'MIUI', 2.0],
#  ['2024-09-15', None, 2.0],
#  ['2024-09-15', 'Firefox', 2.0],
#  ['2024-09-16', 'Opera Mini', 2.0],
#  ['2024-09-16', 'Samsung Internet', 2.0],
#  ['2024-09-16', 'MIUI', 2.0],
#  ['2024-09-18', None, 2.0],
#  ['2024-09-18', 'Opera', 2.0],
#  ['2024-08-01', None, 1.0],
#  ['2024-08-01', 'UCWEB', 1.0],
#  ['2024-08-01', 'WebKit, другие', 1.0],
#  ['2024-08-01', 'WeChat', 1.0],
#  ['2024-08-01', 'MIUI', 1.0],
#  ['2024-08-01', 'YandexBrowserCorp', 1.0],
#  ['2024-08-02', 'Opera', 1.0],
#  ['2024-08-02', 'Opera Mobile', 1.0],
#  ['2024-08-02', 'MQQBrowser', 1.0],
#  ['2024-08-03', 'Opera', 1.0],
#  ['2024-08-03', 'UCWEB', 1.0],
#  ['2024-08-03', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-08-04', None, 1.0],
#  ['2024-08-04', 'Firefox Mobile', 1.0],
#  ['2024-08-04', 'Google: мобильное приложение', 1.0],
#  ['2024-08-04', 'MIUI', 1.0],
#  ['2024-08-05', 'Firefox Mobile', 1.0],
#  ['2024-08-05', 'Google: мобильное приложение', 1.0],
#  ['2024-08-05', 'Samsung Internet', 1.0],
#  ['2024-08-05', 'Яндекс.Браузер lite', 1.0],
#  ['2024-08-06', 'Opera', 1.0],
#  ['2024-08-06', 'Firefox Mobile', 1.0],
#  ['2024-08-06', 'Яндекс.Браузер lite', 1.0],
#  ['2024-08-06', 'Huawei Browser', 1.0],
#  ['2024-08-07', 'MQQBrowser', 1.0],
#  ['2024-08-07', 'Яндекс Старт: мобильное приложение', 1.0],
#  ['2024-08-07', 'Google: мобильное приложение', 1.0],
#  ['2024-08-07', 'Huawei Browser', 1.0],
#  ['2024-08-08', None, 1.0],
#  ['2024-08-08', 'WeChat', 1.0],
#  ['2024-08-08', 'Opera Touch', 1.0],
#  ['2024-08-09', 'WebKit, другие', 1.0],
#  ['2024-08-09', 'Firefox Mobile', 1.0],
#  ['2024-08-09', 'Android Browser', 1.0],
#  ['2024-08-09', 'Google: мобильное приложение', 1.0],
#  ['2024-08-09', 'MIUI', 1.0],
#  ['2024-08-09', 'HeadlessChrome', 1.0],
#  ['2024-08-09', 'YandexBrowserCorp', 1.0],
#  ['2024-08-10', None, 1.0],
#  ['2024-08-10', 'Яндекс Старт: мобильное приложение', 1.0],
#  ['2024-08-10', 'Huawei Browser', 1.0],
#  ['2024-08-11', 'Edge', 1.0],
#  ['2024-08-12', None, 1.0],
#  ['2024-08-12', 'Firefox Mobile', 1.0],
#  ['2024-08-12', 'Samsung Internet', 1.0],
#  ['2024-08-12', 'YandexBrowserCorp', 1.0],
#  ['2024-08-13', 'Samsung Internet', 1.0],
#  ['2024-08-13', 'MIUI', 1.0],
#  ['2024-08-14', None, 1.0],
#  ['2024-08-14', 'UCWEB', 1.0],
#  ['2024-08-14', 'WebKit, другие', 1.0],
#  ['2024-08-14', 'Яндекс Старт: мобильное приложение', 1.0],
#  ['2024-08-14', 'Samsung Internet', 1.0],
#  ['2024-08-14', 'MIUI', 1.0],
#  ['2024-08-14', 'Huawei Browser', 1.0],
#  ['2024-08-15', 'Opera', 1.0],
#  ['2024-08-15', 'Firefox Mobile', 1.0],
#  ['2024-08-15', 'Android Browser', 1.0],
#  ['2024-08-15', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-08-16', 'YandexBrowserCorp', 1.0],
#  ['2024-08-17', None, 1.0],
#  ['2024-08-17', 'Opera Mobile', 1.0],
#  ['2024-08-18', 'Opera Mobile', 1.0],
#  ['2024-08-18', 'Google: мобильное приложение', 1.0],
#  ['2024-08-18', 'Яндекс.Браузер lite', 1.0],
#  ['2024-08-18', 'HeadlessChrome', 1.0],
#  ['2024-08-18', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-08-19', 'UCWEB', 1.0],
#  ['2024-08-19', 'Яндекс Старт: мобильное приложение', 1.0],
#  ['2024-08-19', 'WeChat', 1.0],
#  ['2024-08-19', 'Samsung Internet', 1.0],
#  ['2024-08-20', None, 1.0],
#  ['2024-08-20', 'WeChat', 1.0],
#  ['2024-08-20', 'Opera Touch', 1.0],
#  ['2024-08-20', 'Луна', 1.0],
#  ['2024-08-21', None, 1.0],
#  ['2024-08-21', 'UCWEB', 1.0],
#  ['2024-08-21', 'Samsung Internet', 1.0],
#  ['2024-08-21', 'MIUI', 1.0],
#  ['2024-08-21', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-08-21', 'Луна', 1.0],
#  ['2024-08-22', 'Opera', 1.0],
#  ['2024-08-22', 'UCWEB', 1.0],
#  ['2024-08-22', 'Google: мобильное приложение', 1.0],
#  ['2024-08-22', 'HeadlessChrome', 1.0],
#  ['2024-08-23', None, 1.0],
#  ['2024-08-23', 'Google: мобильное приложение', 1.0],
#  ['2024-08-23', 'Samsung Internet', 1.0],
#  ['2024-08-24', 'Opera', 1.0],
#  ['2024-08-24', 'MIUI', 1.0],
#  ['2024-08-24', 'Opera Touch', 1.0],
#  ['2024-08-25', 'MQQBrowser', 1.0],
#  ['2024-08-25', 'Google: мобильное приложение', 1.0],
#  ['2024-08-25', 'Atom', 1.0],
#  ['2024-08-26', 'Opera', 1.0],
#  ['2024-08-26', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-08-27', None, 1.0],
#  ['2024-08-27', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-08-28', None, 1.0],
#  ['2024-08-28', 'Google: мобильное приложение', 1.0],
#  ['2024-08-28', 'Huawei Browser', 1.0],
#  ['2024-08-28', 'HeadlessChrome', 1.0],
#  ['2024-08-29', 'Opera Mobile', 1.0],
#  ['2024-08-29', 'Яндекс.Браузер lite', 1.0],
#  ['2024-08-29', 'Opera Touch', 1.0],
#  ['2024-08-29', 'YandexBrowserCorp', 1.0],
#  ['2024-08-30', None, 1.0],
#  ['2024-08-30', 'Google: мобильное приложение', 1.0],
#  ['2024-08-30', 'Samsung Internet', 1.0],
#  ['2024-08-31', None, 1.0],
#  ['2024-08-31', 'Opera Mobile', 1.0],
#  ['2024-09-01', 'Firefox', 1.0],
#  ['2024-09-01', 'Opera Mobile', 1.0],
#  ['2024-09-01', 'Firefox Mobile', 1.0],
#  ['2024-09-01', 'Google: мобильное приложение', 1.0],
#  ['2024-09-01', 'HeadlessChrome', 1.0],
#  ['2024-09-01', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-09-02', None, 1.0],
#  ['2024-09-02', 'Samsung Internet', 1.0],
#  ['2024-09-02', 'Huawei Browser', 1.0],
#  ['2024-09-02', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-09-03', 'Opera', 1.0],
#  ['2024-09-03', 'Google: мобильное приложение', 1.0],
#  ['2024-09-03', 'YandexBrowserCorp', 1.0],
#  ['2024-09-04', None, 1.0],
#  ['2024-09-04', 'HeadlessChrome', 1.0],
#  ['2024-09-05', 'Opera Mobile', 1.0],
#  ['2024-09-05', 'Google: мобильное приложение', 1.0],
#  ['2024-09-05', 'Huawei Browser', 1.0],
#  ['2024-09-05', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-09-06', None, 1.0],
#  ['2024-09-06', 'Google: мобильное приложение', 1.0],
#  ['2024-09-06', 'MIUI', 1.0],
#  ['2024-09-07', None, 1.0],
#  ['2024-09-07', 'Firefox Mobile', 1.0],
#  ['2024-09-07', 'MQQBrowser', 1.0],
#  ['2024-09-07', 'Samsung Internet', 1.0],
#  ['2024-09-07', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-09-08', None, 1.0],
#  ['2024-09-08', 'Huawei Browser', 1.0],
#  ['2024-09-09', None, 1.0],
#  ['2024-09-09', 'Opera Touch', 1.0],
#  ['2024-09-09', 'YandexBrowserCorp', 1.0],
#  ['2024-09-10', 'UCWEB', 1.0],
#  ['2024-09-10', 'Firefox Mobile', 1.0],
#  ['2024-09-10', 'Google: мобильное приложение', 1.0],
#  ['2024-09-10', 'Huawei Browser', 1.0],
#  ['2024-09-11', None, 1.0],
#  ['2024-09-11', 'Opera Mobile', 1.0],
#  ['2024-09-11', 'Google: мобильное приложение', 1.0],
#  ['2024-09-11', 'Samsung Internet', 1.0],
#  ['2024-09-12', None, 1.0],
#  ['2024-09-12', 'UCWEB', 1.0],
#  ['2024-09-12', 'Яндекс Старт: мобильное приложение', 1.0],
#  ['2024-09-12', 'MIUI', 1.0],
#  ['2024-09-13', None, 1.0],
#  ['2024-09-13', 'WebKit, другие', 1.0],
#  ['2024-09-13', 'Opera Mobile', 1.0],
#  ['2024-09-13', 'Firefox Mobile', 1.0],
#  ['2024-09-13', 'MIUI', 1.0],
#  ['2024-09-13', 'Huawei Browser', 1.0],
#  ['2024-09-13', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-09-13', 'Phoenix', 1.0],
#  ['2024-09-14', None, 1.0],
#  ['2024-09-14', 'Opera', 1.0],
#  ['2024-09-14', 'Firefox Mobile', 1.0],
#  ['2024-09-14', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-09-15', 'Opera Mini', 1.0],
#  ['2024-09-15', 'UCWEB', 1.0],
#  ['2024-09-15', 'Google: мобильное приложение', 1.0],
#  ['2024-09-15', 'Edge', 1.0],
#  ['2024-09-15', 'Huawei Browser', 1.0],
#  ['2024-09-16', None, 1.0],
#  ['2024-09-16', 'UCWEB', 1.0],
#  ['2024-09-16', 'HeadlessChrome', 1.0],
#  ['2024-09-16', 'Phoenix', 1.0],
#  ['2024-09-17', None, 1.0],
#  ['2024-09-17', 'Яндекс Старт: мобильное приложение', 1.0],
#  ['2024-09-17', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-09-18', 'UCWEB', 1.0],
#  ['2024-09-18', 'Opera Mobile', 1.0],
#  ['2024-09-18', 'WeChat', 1.0],
#  ['2024-09-18', 'MIUI', 1.0],
#  ['2024-09-18', 'Яндекс с Алисой: мобильное приложение', 1.0],
#  ['2024-09-18', 'YandexBrowserCorp', 1.0]]
